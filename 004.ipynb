# %% [markdown]
# # 세자리 수를 곱해 만들 수 있는 가장 큰 대칭수
# Problem 4
#
# 출제 일시 : 2012-01-03 19:11:35, ☕
#
# 앞에서부터 읽을 때나 뒤에서부터 읽을 때나 모양이 같은 수를 대칭수(palindrome)라고 부릅니다.
#
# 두 자리 수를 곱해 만들 수 있는 대칭수 중 가장 큰 수는 9009 (= 91 × 99) 입니다.
#
# 세 자리 수를 곱해 만들 수 있는 가장 큰 대칭수는 얼마입니까?

# %% [markdown]
# 대칭수는 숫자를 문자열로 바꿔 앞뒤를 비교하면 쉽게 구할 수 있다. 세 자리 수를 곱해 만들 수 있는 가장 큰 대칭수를 찾는 문제이므로 999*999이하 대칭수를 찾으면 된다.

# %%
999*999
# Out:
# 998001

# %%
def palindrome(n):
    n = str(n)
    if n == n[::-1]: return True
    return False

# %%
palindrome(999999)
# Out:
# True

# %%
for i in range(999*999)[::-1]:
    if palindrome(i): print(i)
# Out:
# 997799
# 996699
# 995599
# 994499
# 993399
# 992299
# 991199
# 990099
# 989989
# 988889
# 987789
# 986689
# 985589
# 984489
# 983389
# 982289
# 981189
# 980089
# 979979
# 978879
# 977779
# 976679
# 975579
# 974479
# 973379
# 972279
# 971179
# 970079
# 969969
# 968869
# 967769
# 966669
# 965569
# 964469
# 963369
# 962269
# 961169
# 960069
# 959959
# 958859
# 957759
# 956659
# 955559
# 954459
# 953359
# 952259
# 951159
# 950059
# 949949
# 948849
# 947749
# 946649
# 945549
# 944449
# 943349
# 942249
# 941149
# 940049
# 939939
# 938839
# 937739
# 936639
# 935539
# 934439
# 933339
# 932239
# 931139
# 930039
# 929929
# 928829
# 927729
# 926629
# 925529
# 924429
# 923329
# 922229
# 921129
# 920029
# 919919
# 918819
# 917719
# 916619
# 915519
# 914419
# 913319
# 912219
# 911119
# 910019
# 909909
# 908809
# 907709
# 906609
# 905509
# 904409
# 903309
# 902209
# 901109
# 900009
# 899998
# 898898
# 897798
# 896698
# 895598
# 894498
# 893398
# 892298
# 891198
# 890098
# 889988
# 888888
# 887788
# ...

# %% [markdown]
# 아차차, 세자리 수를 곱해서 만들어야 한다는 규칙을 빼먹었다.

# %%
m = 0
for i in range(1000)[::-1]:
    for j in range(1000)[::-1]:
        if palindrome(i*j) and m < i*j:
            m = i*j

print(m)
# Out:
# 906609
